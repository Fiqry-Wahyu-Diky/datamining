# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %cd /content/drive/MyDrive/KULIAH/SEMESTER 5/DATA MINING/datamining
# Out:
# /content/drive/MyDrive/KULIAH/SEMESTER 5/DATA MINING/datamining

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv("Stress-Lysis.csv")
df.head()
# Out:
#    Humidity  Temperature  Step count  Stress Level
# 0     21.33        90.33         123             1
# 1     21.41        90.41          93             1
# 2     27.12        96.12         196             2
# 3     27.64        96.64         177             2
# 4     10.87        79.87          87             0

# %%
df.dtypes
# Out:
# Humidity        float64
# Temperature     float64
# Step count        int64
# Stress Level      int64
# dtype: object

# %%
df.shape
# Out:
# (2001, 4)

# %%
print ("ini data maks\n",df.max())
print("==============================")
print ("ini data min \n",df.min())
# Out:
# ini data maks
#  Humidity         30.0
# Temperature      99.0
# Step count      200.0
# Stress Level      2.0
# dtype: float64
# ...
# ini data min
#  Humidity        10.0
# Temperature     79.0
# Step count       0.0
# Stress Level     0.0
# dtype: float64

# %%
X = df.iloc[:,0:3]
y = df.iloc[:,2]

print (X)
print(y)
# Out:
#       Humidity  Temperature  Step count
# 0        21.33        90.33         123
# 1        21.41        90.41          93
# 2        27.12        96.12         196
# 3        27.64        96.64         177
# 4        10.87        79.87          87
# ...        ...          ...         ...
# 1996     21.82        90.82          96
# 1997     10.45        79.45          45
# 1998     27.22        96.22         135
# 1999     12.46        81.46          64
# 2000     16.87        85.87          50
#
# [2001 rows x 3 columns]
# 0       123
# 1        93
# 2       196
# 3       177
# 4        87
#        ...
# 1996     96
# 1997     45
# 1998    135
# 1999     64
# 2000     50
# Name: Step count, Length: 2001, dtype: int64

# %%
# from pandas._libs.hashtable import duplicated
duplicate_rows = df[df.duplicated()] #mengetahui nilai duplicat
print (duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [Humidity, Temperature, Step count, Stress Level]
# Index: []

# %%
print (df.isnull().sum()) #mengetahui nilai kosong
# Out:
# Humidity        0
# Temperature     0
# Step count      0
# Stress Level    0
# dtype: int64

# %%
# normalisasi/standaritation
scaler = MinMaxScaler()
scaler.fit()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-4a69f7833968> in <module>
#       1 # normalisasi/standaritation
#       2 scaler = MinMaxScaler()
# ----> 3 scaler.fit()
#
# TypeError: fit() missing 1 required positional argument: 'X'

# %%
scaled = scaler.fit_transform(df[['Humidity','Temperature','Step count']])
print (scaled)

# %%
batas_bin = [0,1,2]
